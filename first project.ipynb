# %%
import pandas as pd

# %%
pd.read_excel(r'C:\Users\My Pc\Desktop\practice.xlsx')
# Out:
#    gagan abhijeet  deepika
# 0  chcha      papa     maa
# 1  chahi    baaap      maa
# 2   dada      dadi     NaN
# 3  mamaa      nani    nana

# %%
pd.read_csv(r"C:\Users\My Pc\Desktop\practice csv.csv")
# Out:
#    gagan abhijeet   deepika   boy
# 0  chcha      papa      maa  girl
# 1  chahi    baaap       maa   boy
# 2   dada      dadi      NaN  girl
# 3  mamaa      nani     nana   boy
# 4      s      dadi  deepika  girl
# 5   dada      dadi  deepika   boy

# %%
pd.read_csv(r'C:\Users\My Pc\Desktop\practice.tsv',sep='\t')
# Out:
#      s    j    a    d    g  Unnamed: 5
# 0    9    9    9    9  9.0         NaN
# 1  NaN    2    2    2  2.0         NaN
# 2    1  NaN  NaN  NaN  NaN         NaN
# 3    2    2    2    2  1.0         NaN
# 4    1    1    1    2  NaN         NaN
# 5    j    j    k    h  1.0         NaN
# 6  NaN    1  NaN  NaN  NaN         NaN
# 7    q  NaN    k    l  1.0         NaN
# 8  NaN    1  NaN  NaN  NaN         NaN

# %%
import os

# %%
import pandas as p

# %%
p.read_excel('practice.xlsx')
# Out:
#    gagan abhijeet  deepika
# 0  chcha      papa     maa
# 1  chahi    baaap      maa
# 2   dada      dadi     NaN
# 3  mamaa      nani    nana

# %%
p.read_csv('practice csv.csv')
# Out:
#    gagan abhijeet   deepika   boy
# 0  chcha      papa      maa  girl
# 1  chahi    baaap       maa   boy
# 2   dada      dadi      NaN  girl
# 3  mamaa      nani     nana   boy
# 4      s      dadi  deepika  girl
# 5   dada      dadi  deepika   boy

# %%
p.read_csv('practice.tsv',sep="\t")
# Out:
#      s    j    a    d    g  Unnamed: 5
# 0    9    9    9    9  9.0         NaN
# 1  NaN    2    2    2  2.0         NaN
# 2    1  NaN  NaN  NaN  NaN         NaN
# 3    2    2    2    2  1.0         NaN
# 4    1    1    1    2  NaN         NaN
# 5    j    j    k    h  1.0         NaN
# 6  NaN    1  NaN  NaN  NaN         NaN
# 7    q  NaN    k    l  1.0         NaN
# 8  NaN    1  NaN  NaN  NaN         NaN
